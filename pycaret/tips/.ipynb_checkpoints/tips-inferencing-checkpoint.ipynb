# %%
import pandas as pd
from pycaret.regression import *

# %%
loaded_pipeline = load_model('tips-best')
loaded_pipeline
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['total_bill', 'size'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['sex', 'smoker', 'day', 'time'],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('ordinal_encoding',
#                  TransformerWrapper(include=['sex', 'smoker', 'time'],...
# dtype: int64},
#                                                                         {'col': 'smoker',
#                                                                          'data_type': dtype('O'),
#                                                                          'mapping': No     0
# Yes    1
# NaN   -1
# dtype: int64},
# ...

# %%
infer_data = pd.DataFrame({'total_bill': [30],
                         'sex': ['Female'],
                         'smoker': ['No'],
                         'day': ['Sun'],
                         'time': ['Dinner'],
                         'size': [4]
                        })

# %%
predict_result = predict_model(loaded_pipeline, data=infer_data)
predict_result
# Out:
#    total_bill     sex smoker  day    time  size  prediction_label
# 0          30  Female     No  Sun  Dinner     4          3.895665
