# %%
import pandas as pd
from pycaret.regression import *

# %%
data = pd.read_csv('tips.csv')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
s = setup(data, target = 'tip', session_id = 123)
# Out:
# <style type="text/css">
# #T_805ff_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_805ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_805ff_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_805ff_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_805ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_805ff_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_805ff_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_805ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_805ff_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_805ff_row1_col1" class="data row1 col1" >tip</td>
#     </tr>
#     <tr>
#       <th id="T_805ff_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_f14cd th {
#   text-align: left;
# }
# ...

# %%
new_data = pd.DataFrame({'total_bill': [100],
                         'sex': ['Female'],
                         'smoker': ['Yes'],
                         'day': ['Sun'],
                         'time': ['Dinner'],
                         'size': [4]
                        })
new_data
# Out:
#    total_bill     sex smoker  day    time  size
# 0         100  Female    Yes  Sun  Dinner     4

# %%
new_pred = predict_model(best, data=new_data)
new_pred
# Out:
#    total_bill     sex smoker  day    time  size  prediction_label
# 0         100  Female    Yes  Sun  Dinner     4         10.325378

# %%
new_pred.at[0, 'prediction_label']
# Out:
# 10.325378434724051

# %%
new_data2 = pd.DataFrame({'total_bill': [50],
                         'sex': ['Male'],
                         'smoker': ['Yes'],
                         'day': ['Mon'],
                         'time': ['Lunch'],
                         'size': [2]
                        })
new_data2
# Out:
#    total_bill   sex smoker  day   time  size
# 0          50  Male    Yes  Mon  Lunch     2

# %%
new_pred2 = predict_model(best, data=new_data2)
new_pred2
# Out:
#    total_bill   sex smoker  day   time  size  prediction_label
# 0          50  Male    Yes  Mon  Lunch     2          5.732726

# %%
save_model(best, 'tips-best')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['total_bill', 'size'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['sex', 'smoker', 'day', 'time'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   TransformerWrapper(include=['sex', 'smoker', 'time'],...
#  dtype: int64},
#                                                                          {'col': 'smoker',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': No     0
#  Yes    1
#  NaN   -1
#  dtype: int64},
# ...
