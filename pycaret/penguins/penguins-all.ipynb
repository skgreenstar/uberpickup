# %%
import pandas as pd
from pycaret.classification import *

# %%
data = pd.read_csv('penguins.csv')
data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7                181
# 1    Adelie  Torgersen              39.5             17.4                186
# 2    Adelie  Torgersen              40.3             18.0                195
# 3    Adelie  Torgersen              36.7             19.3                193
# 4    Adelie  Torgersen              39.3             20.6                190
# ..      ...        ...               ...              ...                ...
# 328  Gentoo     Biscoe              47.2             13.7                214
# 329  Gentoo     Biscoe              46.8             14.3                215
# 330  Gentoo     Biscoe              50.4             15.7                222
# 331  Gentoo     Biscoe              45.2             14.8                212
# 332  Gentoo     Biscoe              49.9             16.1                213
#
#      body_mass_g     sex
# 0           3750    MALE
# 1           3800  FEMALE
# 2           3250  FEMALE
# 3           3450  FEMALE
# 4           3650    MALE
# ..           ...     ...
# 328         4925  FEMALE
# 329         4850  FEMALE
# 330         5750    MALE
# 331         5200  FEMALE
# 332         5400    MALE
#
# [333 rows x 7 columns]

# %%
data.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        333.000000       333.000000         333.000000   333.000000
# mean          43.992793        17.164865         200.966967  4207.057057
# std            5.468668         1.969235          14.015765   805.215802
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.500000        15.600000         190.000000  3550.000000
# 50%           44.500000        17.300000         197.000000  4050.000000
# 75%           48.600000        18.700000         213.000000  4775.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
s = setup(data, target = 'species', session_id = 123)
# Out:
# <style type="text/css">
# #T_d5a4b_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d5a4b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5a4b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d5a4b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5a4b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5a4b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d5a4b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5a4b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d5a4b_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5a4b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d5a4b_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5a4b_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_d5a4b_row3_col1" class="data row3 col1" >Adelie: 0, Chinstrap: 1, Gentoo: 2</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5a4b_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_d5a4b_row4_col1" class="data row4 col1" >(333, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d5a4b_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_d5a4b_row5_col1" class="data row5 col1" >(333, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d5a4b_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_d5a4b_row6_col1" class="data row6 col1" >(233, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d5a4b_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_d5a4b_row7_col1" class="data row7 col1" >(100, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d5a4b_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_d5a4b_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d5a4b_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_d5a4b_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d5a4b_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_d5a4b_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d5a4b_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_d5a4b_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d5a4b_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_d5a4b_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d5a4b_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_d5a4b_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d5a4b_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_d5a4b_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d5a4b_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_d5a4b_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d5a4b_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_d5a4b_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d5a4b_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_d5a4b_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d5a4b_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_d5a4b_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d5a4b_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_d5a4b_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d5a4b_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_d5a4b_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d5a4b_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_d5a4b_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d5a4b_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_d5a4b_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d5a4b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d5a4b_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_d5a4b_row23_col1" class="data row23 col1" >5006</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T
row6_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_88a04_row0_col8, #T_88a04_row2_col8, #T_88a04_row3_col8, #T_88a04_row4_col8, #T_88a04_row5_col8, #T_88a04_row6_col8, #T_88a04_row7_col8, #T_88a04_row8_col8, #T_88a04_row9_col8, #T_88a04_row10_col8, #T_88a04_row11_col8, #T_88a04_row12_col8, #T_88a04_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_88a04_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_88a04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88a04_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_88a04_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_88a04_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_88a04_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_88a04_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_88a04_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_88a04_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_88a04_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_88a04_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88a04_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_88a04_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_88a04_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_88a04_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_88a04_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_88a04_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_88a04_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_88a04_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_88a04_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_88a04_row0_col8" class="data row0 col8" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_88a04_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_88a04_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_88a04_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_88a04_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_88a04_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_88a04_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_88a04_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_88a04_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_88a04_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_88a04_row1_col8" class="data row1 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_88a04_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_88a04_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_88a04_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_88a04_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_88a04_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_88a04_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_88a04_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_88a04_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_88a04_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_88a04_row2_col8" class="data row2 col8" >0.0750</td>
#     </tr>
#     <tr>
#       <th id="T_88a04_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_88a04_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_88a04_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_88a04_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_88a04_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_88a04_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_88a04_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_88a04_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_88a04_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_88a04_row3_col8" class="data row3 col8" >1.0830</td>
#     </tr>
#     <tr>
#       <th id="T_88a04_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_88a04_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_88a04_row4_col1" class="data row4 col1" >0.9957</td>
#       <td id="T_88a04_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_88a04_row4_col3" class="data row4 col3" >0.9957</td>
#       <td id="T_88a04_row4_col4" class="data row4 col4" >0.9960</td>
#       <td id="T_88a04_row4_col5" class="data row4 col5" >0.9955</td>
#       <td id="T_88a04_row4_col6" class="data row4 col6" >0.9931</td>
#       <td id="T_88a04_row4_col7" class="data row4 col7" >0.9934</td>
#       <td id="T_88a04_row4_col8" class="data row4 col8" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_88a04_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_88a04_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_88a04_row5_col1" class="data row5 col1" >0.9913</td>
#       <td id="T_88a04_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_88a04_row5_col3" class="data row5 col3" >0.9913</td>
#       <td id="T_88a04_row5_col4" class="data row5 col4" >0.9924</td>
#       <td id="T_88a04_row5_col5" class="data row5 col5" >0.9912</td>
#       <td id="T_88a04_row5_col6" class="data row5 col6" >0.9865</td>
#       <td id="T_88a04_row5_col7" class="data row5 col7" >0.9870</td>
#       <t

# %%
new_data = pd.DataFrame({'island': ['Biscoe'],
                         'culmen_length_mm': [50.5],
                         'culmen_depth_mm': [15.1],
                         'flipper_length_mm': [210],
                         'body_mass_g': [5000],
                         'sex': ['MALE']
                        })
new_data
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Biscoe              50.5             15.1                210         5000
#
#     sex
# 0  MALE

# %%
new_pred = predict_model(best, data=new_data)
new_pred
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Biscoe              50.5             15.1                210         5000
#
#     sex prediction_label  prediction_score
# 0  MALE           Gentoo              0.98

# %%
new_pred.at[0, 'prediction_label']
# Out:
# 'Gentoo'

# %%
save_model(best, 'penguins-best')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['culmen_length_mm',
#                                               'culmen_depth_mm',
#                                               'flipper_length_mm',
#                                               'body_mass_g'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=N...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          n_estimators=100, n_jobs=-1,
#                                          oob_score=False, random_state=123,
#                                          verbose=0, warm_start=False))],
#           verbose=False),
#  'penguins-best.pkl')
